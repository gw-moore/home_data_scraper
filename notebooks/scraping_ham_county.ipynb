# %%
from bs4 import BeautifulSoup
import requests

# %%
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %%
postfixes = [
    'summary',
    'appraisal',
]

parcel_num = "5500081001500"

# %%
# prep request
with requests.Session() as s:
    url = f'https://wedge1.hcauditor.org/view/re/{parcel_num}/2019/summary'
    r = s.get(url, headers=req_headers)

# %%
# get page text
soup = BeautifulSoup(r.content, 'lxml')

# %%
soup.find('td', text='Last Sale Amount').find_next_sibling().text
# Out:
# '$118,000'

# %%
soup.find('td', text='Year Built').find_next_sibling().text
# Out:
# '1948'

# %%
soup.find('td', text='Year Built').find_next_sibling().text

# %%
soup.find('td', text='Last Sale Date').find_next_sibling().text
# Out:
# '1/16/2020'

# %%
soup.find('span', {'label', 'Parcel ID'}).find_next_sibling().find_next_sibling()

# %%
# ?soup.find
# Out:
# Signature: soup.find(name=None, attrs={}, recursive=True, text=None, **kwargs)
# Docstring:
# Look in the children of this PageElement and find the first
# PageElement that matches the given criteria.
#
# All find_* methods take a common set of arguments. See the online
# documentation for detailed explanations.
#
# :param name: A filter on tag name.
# :param attrs: A dictionary of filters on attribute values.
# :param recursive: If this is True, find() will perform a
#     recursive search of this PageElement's children. Otherwise,
#     only the direct children will be considered.
# :param limit: Stop looking after finding this many results.
# :kwargs: A dictionary of filters on attribute values.
# :return: A PageElement.
# :rtype: bs4.element.PageElement
# File:      ~/anaconda3/lib/python3.7/site-packages/bs4/element.py
# Type:      method

# %%
soup.body
# Out:
# <body>
# <div id="frame">
# <div class="ui-helper-clearfix" id="header">
# <div id="sitelogo">
# <a href="https://www.hamiltoncountyauditor.org"><img alt="Dusty Rhodes, Hamilton County Auditor" src="/Images/logo_noborder.png"/></a>
# </div>
# </div>
# <div class="ui-widget">
# <div class="ui-widget-header head2" id="sectiontitle">
# <div style="float:left">Online Property Access</div>
# <span class="ui-helper-clearfix"></span>
# </div>
# </div>
# <div class="ui-widget" id="content" role="main">
# <div id="parcel-header-info">
# <div style="width:20%;">
# <span class="label">Parcel ID</span><br/>
#         550-0081-0015-00
#     </div>
# <div style="width:25%;">
# <span class="label">Address</span><br/>
#         5655 CHEVIOT RD
#     </div>
# <div style="width:20%;">
# <span class="label">Index Order</span><br/>
#         Parcel Number
#     </div>
# <div style="width:20%;">
# <span class="label">Tax Year</span><br/>
#         2019
#         Payable 2020
#     </div>
# </div>
# <div id="ajaxDiv">
# <style>
#     #tax-credit-value-summary td a {text-decoration:underline;}
# </style>
# <table class="datagrid ui-widget" id="property_information" summary="Property Information">
# <thead class="ui-state-active">
# <tr> <th class="head3" colspan="3"> Property Information </th> </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="2">
# <div class="label" style="display:inline-block; width:110px;">Tax District</div>
# <div style="display:inline-block; width:400px;">142 - GREEN TWP-NORTHWEST LSD</div>
# <br/>
# <div class="label" style="display:inline-block; width:110px;">School District</div>
# <div style="display:inline-block; width:400px;">NORTHWEST LSD (HAMILTON CO.)</div>
# </td>
# <td rowspan="3">
# <div class="label">Images/Sketches</div>
# <a href="/view/re/5500081001500/2019/images"><img alt="Photo 3/23/2015" src="/ASRIMG/Good_to_upload\510_single_family_dwlg/550-0081-0015-00.jpg" style="width:150px; height:115px;"/></a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="label">Appraisal Area</div>
# <div>55007 - GREEN 07</div>
# <div class="noprint"> <a href="/sales_report/55007" id="showSalesReport">Sales</a> </div>
# </td>
# <td>
# <div class="label">Land Use</div>
# <div>471 - DWELLING USED AS RETAIL</div>
# </td>
# </tr>
# <tr>
# <td>
# <div class="label">Owner Name and Address</div>
# <div style="white-space:pre-line">KHEID'S BUILDING LLC
# 1530 BALDRIDGE CT
# HARRISON OH 45030
# </div>
# <div class="red">(call 946-4015 if incorrect)</div>
# </td>
# <td>
# <div class="label">Mailing Name and Address</div>
# <div style="white-space:pre-line">KHEID'S BUILDING LLC
# 1530 BALDRIDGE CT
# HARRISON OH 45030
# </div>
# <div class="red">(call 946-4800 if incorrect)</div>
# </td>
# </tr>
# <tr>
# <td>
# <div class="label">Assessed Value</div>
# <div>55,410</div>
# </td>
# <td>
# <div class="label">Effective Tax Rate</div>
# <div>84.479529</div>
# </td>
# <td>
# <div class="label">Total Tax</div>
# <div>$4,757.83</div>
# </td>
# </tr>
# <tr>
# <td colspan="3">
# <div class="label">Property Description</div>
# <div>5655 CHEVIOT RD 100 X 275
# IRR R2-T2-S12 SW PARS 15-
# 185 CONS
#                          </div>
# </td>
# </tr>
# </tbody>
# </table>
# <div class="datagrid ui-widget" id="property_overview_wrapper">
# <table class="datagrid ui-widget summary" summary="Appraisal Summary">
# <thead class="ui-state-active">
# <tr class="subheading"> <th colspan="2"> Appraisal/Sales Summary </th> </tr>
# </thead>
# <tbody>
# <tr>
# <td>Year Built</td>
# <td>1948</td>
# </tr>
# <tr>
# <td>Total Rooms</td>
# <td>10</td>
# </tr>
# <tr>
# <td># Bedrooms</td>
# <td>0</td>
# </tr>
# <tr>
# <td># Full Bathrooms</td>
# <td>1</td>
# </tr>
# <tr>
# <td># Half Bathrooms</td>
# <td>1</td>
# </tr>
# <tr>
# <td>Last Sale Date</td>
# <td>1/16/2020</td>
# </tr>
# <tr>
# <td>Last Sale Amount</td>
# <td>$118,000</td>
# </tr>
# <tr>
# <td>Conveyance Number</td>
# <td>225082</td>
# </tr>
# <tr>
# <td>Deed Type</td>
# <td>WD - Warranty Deed (Conv)</td>
# </tr>
# <tr>
# <td>Deed Number</td>
# <td></td>
# </tr>
# <tr>
# <td># of Parcels Sold</td>
# <td>1</td>
# </tr>
# <tr>
# <td>Acreage</td>
# <td>0.745</td>
# </tr>
# </tbody>
# </table>
# <table class="datagrid ui-widget summary" id="tax-credit-value-summary" summary="Tax/Credit/Value Summary">
# <thead class="ui-state-active">
# <tr class="subheading"> <th colspan="2"> Tax/Credit/Value Summary </th> </tr>
# </thead>
# <tbody>
# <tr>
# <td>Board of Revision</td>
# <td>No</td>
# </tr>
# <tr>
# <td>Rental Registration</td>
# <td>No</td>
# </tr>
# <tr>
# <td>Homestead</td>
# <td>No</td>
# </tr>
# <tr>
# <td>Owner Occupancy Credit</td>
# <td>No</td>
# </tr>
# <tr>
# <td>Foreclosure</td>
# <td>No</td>
# </tr>
# <tr>
# <td>Special Assessments</td>
# <td>Yes</td>
# </tr>
# <tr>
# <td>Market Land Value</td>
# <td>120,400</td>
# </tr>
# <tr>
# <td>CAUV Value</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Market Improvement Value</td>
# <td>37,900</td>
# </tr>
# <tr>
# <td>Market Total Value</td>
# <td>158,300</td>
# </tr>
# <tr>
# <td>TIF Value</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Abated Value</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Exempt Value</td>
# <td>0</td>
# </tr>
# <tr>
# <td><a href="/view/re/5500081001500/2019/tax_distributions">Taxes Paid</a></td>
# <td>$4,757.83</td>
# </tr>
# <tr>
# <td>Tax as % of Total Value</td>
# <td>0.000%</td>
# </tr>
# </tbody>
# </table>
# </div>
# <table class="datagrid ui-widget" summary="Notes">
# <thead class="ui-state-active">
# <tr class="subheading"> <th colspan="2"> Notes </th> </tr>
# </thead>
# <tbody>
# <tr> <td></td> </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="ui-helper-clearfix">
# <div class="ui-widget" id="sidebar">
# <div class="ui-widget-header ui-corner-top sidebar-title">I Want To...</div>
# <div class="box ui-widget-content ui-corner-bottom">
# <a href="/"><span class="ui-icon ui-icon-search" style="float:left;"></span> Start a New Search</a>
# <a href="/page/EmailTheAssessor"><span class="ui-icon ui-icon-comment" style="float:left;"></span> Email the Auditor</a>
# <a href="/page/Help"><span class="ui-icon ui-icon-help" style="float:left;"></span> View the Online Help</a>
# <a href="https://www.hamiltoncountyauditor.org"><span class="ui-icon ui-icon-home" style="float:left;"></span> Auditor's Home</a>
# <div data-current-tab="/view/re/5500081001500/2019/summary" id="parcel-tabs">
# <hr/>
# <div class="bold">View:</div>
# <a href="/view/re/5500081001500/2019/summary">Property Summary</a>
# <a href="/view/re/5500081001500/2019/appraisal">Appraisal Information</a>
# <a href="/view/re/5500081001500/2019/levies">Levy Information</a>
# <a href="/view/re/5500081001500/2019/transfers">Transfer</a>
# <a href="/view/re/5500081001500/2019/value_history">Value History</a>
# <a href="/view/re/5500081001500/2019/board_of_revision">Board of Revision</a>
# <a href="/view/re/5500081001500/2019/payment_details">Payment Detail</a>
# <a href="/view/re/5500081001500/2019/tax_distributions">Tax Distributions</a>
# <a href="/view/re/5500081001500/2019/images">Images</a>
# <a href="/view/re/5500081001500/2019/special_assessments">Special Assessment/Payoff</a>
# <a href="/view/re/5500081001500/2019/tax_lien">Tax Lien Certificates</a>
# <a href="/view/re/5500081001500/2019/cagis_map">CAGIS Online Maps</a>
# <a href="/view/re/5500081001500/2019/aerial_imagery">Aerial Imagery</a>
# <a href="/view/re/5500081001500/2019/names">Owner Names</a>
# </div>
# <div id="print-links">
# <hr/>
# <div class="bold">Print:</div>
# <a href="/view/re/5500081001500/2019/print_current" id="print-current" target="_blank"><span class="ui-icon ui-icon-print" style="float:left;"></span> Current Page</a>
# <a href="/view/re/5500081001500/2019/print_select" target="_blank"><span class="ui-icon ui-icon-print" style="float:left;"></span> Property Report</a>
# </div>
# </div>
# </div>
# </div>
# <div class="ui-helper-clearfix" id="footer">
# <hr/>
# <div class="para" id="copyright" style="float: left;">
#                 Copyright © 2009-2020, <a href="https://www.devnetinc.com">DEVNET, Inc.</a> All rights reserved. <br/>
#                 wEdge version 4.0.7480.17247 <br/>
#                 Data updated: 2020/07/11
#             </div>
# <div class="para" style="float: right;">
# <a href="/page/LegalDisclaimer">Legal Disclaimer</a> |
#                 <a href="/page/PrivacyPolicy">Privacy Statement</a>
# </div>
# </div>
# </div>
# <script src="/Scripts/jquery-1.11.3.min.js"></script>
# <script src="/Scripts/jquery-migrate-1.2.1.min.js"></script>
# <script src="/Scripts/DataTables/jquery.dataTables.min.js"></script>
# <script src="/Scripts/jquery.tablesorter.min.js"></script>
# <script src="/Scripts/jquery.maskedinput-1.4.min.js"></script>
# <script src="/Scripts/jquery.multi-select.js"></script>
# <script src="/Scripts/jquery.blockUI.min.js"></script>
# <script src="/Scripts/jquery.galleriffic.js"></script>
# <script src="/Scripts/jquery-ui-1.8.23.min.js"></script>
# <script src="/Scripts/moment.min.js"></script>
# <script src="/Scripts/accounting.min.js"></script>
# <script src="/Scripts/wEdge.js"></script>
# <script src="https://www.google.com/recaptcha/api.js"></script>
# <script async="" data-authorized="false" data-children="false" data-controls="false" data-current-id="6ef70a4c-c530-4d73-929e-1cf985dcc9db" data-ids="6ef70a4c-c530-4d73-929e-1cf985dcc9db" data-max-traces="15" data-path="/mini-profiler-resources/" data-position="left" data-start-hidden="true" data-toggle-shortcut="Alt+P" data-trivial="false" data-trivial-milliseconds="2" data-version="ySF6M98CBehTtL86BbiEmys9yxR1HKazhe2sznfdUWQ=" id="mini-profiler" src="/mini-profiler-resources/includes.js?v=ySF6M98CBehTtL86BbiEmys9yxR1HKazhe2sznfdUWQ=" type="text/javascript"></script>
# </body>

# %%
# find all card info
home_info = soup.find_all('div', {'class': 'list-card-info'})
